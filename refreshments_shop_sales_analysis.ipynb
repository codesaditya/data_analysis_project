# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df  = pd.read_csv(r"C:\Users\adity\OneDrive\Desktop\D.A_project\Project.csv")
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       01-06-2023         11:33:29         3        Astoria
# 1          115405       02-06-2023         11:18:24         3        Astoria
# 2          115478       02-06-2023         12:02:45         3        Astoria
# 3          116288       02-06-2023         19:39:47         3        Astoria
# 4          116714       03-06-2023         12:24:57         3        Astoria
#
#    product_id  transaction_qty  unit_price  Total_Bill product_category  \
# 0          45                1         3.0         3.0              Tea
# 1          45                1         3.0         3.0              Tea
# 2          45                1         3.0         3.0              Tea
# 3          45                1         3.0         3.0              Tea
# 4          45                1         3.0         3.0              Tea
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  object
#  2   transaction_time  149116 non-null  object
#  3   store_id          149116 non-null  int64
#  4   store_location    149116 non-null  object
#  5   product_id        149116 non-null  int64
#  6   transaction_qty   149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   Total_Bill        149116 non-null  float64
#  9   product_category  149116 non-null  object
#  10  product_type      149116 non-null  object
#  11  product_detail    149116 non-null  object
#  12  Size              149116 non-null  object
#  13  Month Name        149116 non-null  object
#  14  Day Name          149116 non-null  object
#  15  Hour              149116 non-null  int64
# ...

# %%
df.describe()
# Out:
#        transaction_id       store_id     product_id  transaction_qty  \
# count   149116.000000  149116.000000  149116.000000    149116.000000
# mean     74737.371872       5.342063      47.918607         1.438276
# std      43153.600016       2.074241      17.930020         0.542509
# min          1.000000       3.000000       1.000000         1.000000
# 25%      37335.750000       3.000000      33.000000         1.000000
# 50%      74727.500000       5.000000      47.000000         1.000000
# 75%     112094.250000       8.000000      60.000000         2.000000
# max     149456.000000       8.000000      87.000000         8.000000
#
#           unit_price     Total_Bill           Hour          Month  \
# count  149116.000000  149116.000000  149116.000000  149116.000000
# mean        3.382219       4.686367      11.735790       3.988881
# std         2.658723       4.227099       3.764662       1.673091
# min         0.800000       0.800000       6.000000       1.000000
# ...

# %%
df = df.drop(columns=['Month Name','Day Name','Hour','Month','Day of Week','store_location'])
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id  product_id  \
# 0          114301       01-06-2023         11:33:29         3          45
# 1          115405       02-06-2023         11:18:24         3          45
# 2          115478       02-06-2023         12:02:45         3          45
# 3          116288       02-06-2023         19:39:47         3          45
# 4          116714       03-06-2023         12:24:57         3          45
#
#    transaction_qty  unit_price  Total_Bill product_category  \
# 0                1         3.0         3.0              Tea
# 1                1         3.0         3.0              Tea
# 2                1         3.0         3.0              Tea
# 3                1         3.0         3.0              Tea
# 4                1         3.0         3.0              Tea
#
#         product_type product_detail   Size
# 0  Brewed herbal tea     Peppermint  Large
# 1  Brewed herbal tea     Peppermint  Large
# ...

# %% [markdown]
# **Product Category**

# %%
df['product_category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='product_category'>

# %%
df['product_category'].describe()
# Out:
# count     149116
# unique         9
# top       Coffee
# freq       58416
# Name: product_category, dtype: object

# %% [markdown]
# This visualisation shows that 'Coffee' is the most preffered product with 58416 entries among 149116 entries having 9 categories of products.Then, tea is the next most preferred product followed by bakery items.

# %% [markdown]
# **Product Detail**

# %%
df['product_detail'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['product_detail'].describe()
# Out:
# count                       149116
# unique                          45
# top       Our Old Time Diner Blend
# freq                          8660
# Name: product_detail, dtype: object

# %%
df0=df[['product_category']][df.product_detail=='Our Old Time Diner Blend']
df0.head()
# Out:
#      product_category
# 8131           Coffee
# 8132           Coffee
# 8133           Coffee
# 8134           Coffee
# 8135           Coffee

# %% [markdown]
# The plot above provides an overview of the product detail dataset. It consists of 149116 entries, with 45 unique product details reported by the refreshments shop. The most frequently reported product is "Our Old Time Diner Blend" which is a type of coffee, appearing 8660 times in the dataset. This indicates a significant interest among consumers in this product. The summary underscores the diverse range of product details provided by the refreshments shop, with various fields represented in the dataset. Additionally, it highlights the prominence of "Our Old Time Diner Blend" as a popular product among the consumers

# %% [markdown]
# **Product Type**

# %%
df['product_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='product_type'>

# %%
df['product_type'].describe()
# Out:
# count              149116
# unique                 29
# top       Brewed Chai tea
# freq                17183
# Name: product_type, dtype: object

# %% [markdown]
# The plot above provides an overview of the product type dataset. It consists of 149116 entries, with 29 unique product types reported by the refreshments shop. The most frequently reported product type is "Brewed Chai tea", appearing 17183 times in the dataset. This indicates a significant interest among consumers in this product type. The summary underscores the diverse range of product types provided by the refreshments shop, with various fields represented in the dataset. Additionally, it highlights the prominence of the Brewed Chai tea as a popular product type among the consumers.

# %% [markdown]
# **Store**

# %%
data=df['store_id']
sns.histplot(data)
# Out:
# <Axes: xlabel='store_id', ylabel='Count'>

# %%
df['store_id'].describe()
# Out:
# count    149116.000000
# mean          5.342063
# std           2.074241
# min           3.000000
# 25%           3.000000
# 50%           5.000000
# 75%           8.000000
# max           8.000000
# Name: store_id, dtype: float64

# %% [markdown]
# The above visualisation tells that maximum orders are taken from store with id-8 and minimum from store with id-3.  If we had other details, we can see why maximum orders are from store with id-8 and try to implement these in other stores as well to get maximum profit.

# %% [markdown]
# **Maximum sold coffee**

# %%
df1=df[df.product_category=='Coffee']
df1.head()
# Out:
#       transaction_id transaction_date transaction_time  store_id  product_id  \
# 8131              67       01-01-2023         09:44:46         5          24
# 8132             558       02-01-2023         07:25:59         5          24
# 8133             776       02-01-2023         13:15:40         5          24
# 8134            1782       04-01-2023         11:11:46         5          24
# 8135            2004       04-01-2023         15:28:03         5          24
#
#       transaction_qty  unit_price  Total_Bill product_category product_type  \
# 8131                1         3.0         3.0           Coffee  Drip coffee
# 8132                1         3.0         3.0           Coffee  Drip coffee
# 8133                1         3.0         3.0           Coffee  Drip coffee
# 8134                1         3.0         3.0           Coffee  Drip coffee
# 8135                1         3.0         3.0           Coffee  Drip coffee
#
#                 product_detail   Size
# ...

# %%
df1['product_type'].describe()
# Out:
# count                     58416
# unique                        5
# top       Gourmet brewed coffee
# freq                      16912
# Name: product_type, dtype: object

# %% [markdown]
# The above details suggest that there are 5 unique types of Coffee's in the shop and in them, 'Gourmet brewed coffee' is the most preferred product with frequency of 16912.

# %%
df1['product_detail'].describe()
# Out:
# count         58416
# unique            9
# top       Brazilian
# freq           8489
# Name: product_detail, dtype: object

# %% [markdown]
# The above details suggest that in 9 different Coffee types, Brazilian Coffee is the most preferred one among consumers with frequency of 8489.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# Analysis of data from 149116 transactions in a refreshments shop revealed different trends and patterns. The most frequently reported product type is "Brewed Chai tea",which shows its popularity among consumers.The most frequently reported product is "Our Old Time Diner Blend" which is a type of coffee. Coffee is the most ordered product.The maximum orders are taken from store with id-8. In Coffee's, 'Gourmet brewed coffee' is the most preferred product_type and Brazilian coffee is the most preferred product_detail. In essence, comprehensive analysis provides valuable insights of the dataset enabling informed decision making in the store.
